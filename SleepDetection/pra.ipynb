# %%
import cv2
cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt2.xml')

# %%
import matplotlib.pyplot as plt
img = cv2.imread("/Users/yamada/Documents/TUS/3年/後期/応用情報工学演習/谷口研/課題/gw/SleepDetection/boy.jpg")
cv2.imshow("image", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
print(img.shape)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) # OpenCV は色がGBR順なのでRGB順に並べ替える
plt.show()
# Out:
# (1600, 2560, 3)
